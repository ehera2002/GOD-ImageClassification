# %%
import turicreate as tc

# %%
import pandas as pd

# %%
from collections import Counter

# %% [markdown]
# ### Load Processed Data

# %%
data_set = tc.load_sframe('ClassificationDataset.sframe/')

# %%
data_set
# Out:
# Columns:
# 	ImageID	str
# 	deep_features	array
# 	DisplayName	str
#
# Rows: 33065804
#
# Data:
# +------------------+-------------------------------+-----------------+
# |     ImageID      |         deep_features         |   DisplayName   |
# +------------------+-------------------------------+-----------------+
# | 000002b66c9c498e | [0.25520071387290955, 0.0,... |     Birthday    |
# | 000002b66c9c498e | [0.25520071387290955, 0.0,... |    Friendship   |
# | 000002b66c9c498e | [0.25520071387290955, 0.0,... |     Cuisine     |
# | 000002b66c9c498e | [0.25520071387290955, 0.0,... |      Event      |
# | 000002b66c9c498e | [0.25520071387290955, 0.0,... |      Torte      |
# | 000002b66c9c498e | [0.25520071387290955, 0.0,... | Cake decorating |
# | 000002b66c9c498e | [0.25520071387290955, 0.0,... |   Anniversary   |
# | 000002b66c9c498e | [0.25520071387290955, 0.0,... |      Party      |
# | 000002b66c9c498e | [0.25520071387290955, 0.0,... |    Community    |
# ...

# %%
num_data = Counter(data_set['DisplayName'])
num_data = num_data.items()
num_data = sorted(num_data, key=lambda x: x[1], reverse=True)

# %% [markdown]
# ### Split Data Into Categories for Saving Time and Memory

# %%
# categories whose number exists in [100000, 300000)
category1 = [i for i, j in num_data if 100000 <= j < 300000]
len(category1)
# Out:
# 72

# %%
print(category1)
# Out:
# ['Design', 'Human', 'Organ (Biology)', 'Black', 'Male person', 'Architecture', 'Tree', 'Nature', 'Beauty', 'White', 'Light', 'Town', 'Plant', 'Public space', 'Lighting', 'Green', 'Infrastructure', 'Fun', 'Photography', 'Vehicle', 'Morning', 'Event', 'Adult', 'Social group', 'Building', 'Youth', 'Property', 'Daytime', 'Vertebrate', 'Human settlement', 'Sky', 'Human head', 'Clothing', 'Mammal', 'Human body', 'Atmosphere of earth', 'Landmark', 'Phenomenon', 'Blue', 'Land vehicle', 'Spring (Season)', 'Standing', 'Hairstyle', 'Transport', 'Community', 'Line', 'Interaction', 'Woman', 'Red', 'Facial expression', 'Wall', 'Human hair', 'Landscape', 'Vegetation', 'Biome', 'Fashion', 'City', 'Limb', 'Human face', 'Room', 'Urban area', 'Real estate', 'Human eye', 'Grass', 'Natural environment', 'Yellow', 'Facade', 'Lady', 'Recreation', 'Mode of transport', 'Adolescent', 'Leaf']

# %%
# categories whose number exists in [30000, 100000)
category2 = [i for i, j in num_data if 30000 <= j < 100000]
len(category2)
# Out:
# 144

# %%
print(category2)
# Out:
# ['Body of water', 'Product', 'Woody plant', 'Street', 'Botany', 'Water', 'Textile', 'Neighbourhood', 'Brown', 'Stock photography', 'Metropolitan area', 'Leisure', 'Human arm', 'Temple (Body Part)', 'Ecoregion', 'Text', 'Road', 'Car', 'Summer', 'Skin', 'Rural area', 'Material property', 'Art', 'Food', 'Wilderness', 'Smile', 'Style', 'Human leg', 'Nature reserve', 'Chin', 'Black-and-white', 'Joint', 'Home', 'Organism', 'Cuisine', 'Flower', 'Monochrome', 'Residential area', 'Motor vehicle', 'House', 'Metropolis', 'Muscle', 'Dish', 'Tourism', 'Waterway', 'Pink', 'Cool', 'Sunlight', 'Branch', 'Human mouth', 'Forehead', 'Human hand', 'Flowering plant', 'Cloud', 'Close-up', 'Mixed-use', 'Crowd', 'Human nose', 'Monochrome photography', 'Outerwear', 'Ingredient', 'Headgear', 'Vacation', 'Font', 'Technology', 'Footwear', 'Thoroughfare', 'Automotive wheel system', 'Sports', 'Friendship', 'Grass family', 'World', 'Girl', 'Natural landscape', 'Cheek', 'Downtown', 'Produce', 'Interior design', 'Ni
# ...

# %%
# categories whose number exists in [10000, 30000)
category3 = [i for i, j in num_data if 10000 <= j < 30000]
len(category3)
# Out:
# 287

# %%
print(category3)
# Out:
# ['Estate', 'Urban design', 'Grassland', 'Petal', 'Commercial building', 'European food', 'Tower block', 'Musical instrument', 'Human ear', 'Grey', 'Team', 'Glasses', 'Dude', 'Glass', 'Wheel', 'Shrub (Plant)', 'Floor', 'Suit', 'Gentleman', 'Tarmac', 'Boat', 'Signage', 'Plant stem', 'Meadow', 'Vision care', 'Sport venue', 'Snow', 'Watercraft', 'Flooring', 'Channel', 'Geology', 'Metal', 'Sedan', 'Rock', 'Medieval architecture', 'Condominium', 'History', 'Lake', 'Place of worship', 'Fashion accessory', 'Music', 'National park', 'Flavor', 'State park', 'Auto part', 'Black hair', 'Advertising', 'Coupé', 'Family car', 'Jaw', 'Soil', 'Classical architecture', 'Drink', 'Performing arts', 'Tower', 'Blond', 'Formal wear', 'Competition event', 'Mountain', 'Businessperson', 'Apartment', 'Skyscraper', 'Hill', 'Luxury vehicle', 'Sculpture', 'Garden', 'White-collar worker', 'Team sport', 'Player', 'Ocean', 'Wildflower', 'T-shirt', 'Invertebrate', 'Cityscape', 'Canidae', 'Toddler', 'Brown hair', 'Gam
# ...

# %%
# categories whose number exists in [5000, 10000)
category4 = [i for i, j in num_data if 5000 <= j < 10000]
len(category4)
# Out:
# 288

# %%
print(category4)
# Out:
# ['Electrical supply', 'Maroon', 'Door', 'Rolling stock', 'Commercial vehicle', 'Village', 'Tradition', 'Tropics', 'Trail', 'Religion', 'Palace', 'Chapel', 'Square', 'Autumn', 'Riparian zone', 'Palm tree', 'Performance car', 'Listed building', 'Floodplain', 'Temperate coniferous forest', 'À la carte food', 'Still life', 'Pine family', 'Subcompact car', 'Full-size car', 'Eyelash', 'Sound (Geography)', 'Wetland', 'Ancient history', 'Laugh', 'Hair coloring', 'Terrain', 'Train', 'Abdomen', 'Sweetness', 'Singing', 'Waist', 'Wing', 'Family', 'Parking', 'Graphics', 'Drawing', 'Baby', 'Classical sculpture', 'Cobalt blue', 'Moustache', 'Jeans', 'Music venue', 'Mansion', 'Chair', 'Bayou', 'Thumb', 'Bumper', 'Botanical garden', 'Dance', 'Vegetable', 'Texture', 'Wave', 'Snack', 'Brickwork', 'Racing', 'Military uniform', 'Breakfast', 'Concrete', 'Machine', 'Sunrise', 'Helmet', 'Companion dog', 'Marketplace', 'Alloy wheel', 'Pollinator', 'Military person', 'Ship', 'Adventure', 'Hardtop', 'Sportswea
# ...

# %%
# categories whose number exists in [3000, 5000)
category5 = [i for i, j in num_data if 3000 <= j < 5000]
len(category5)
# Out:
# 299

# %%
print(category5)
# Out:
# ['Naval architecture', 'Figurine', 'Antique car', 'Soccer player', 'Crop (Plant)', 'Wedding dress', 'Wedding', 'Steel', 'Perching bird', 'Reflecting pool', 'Serveware', 'Air force', 'European shorthair', 'Fried food', 'Herb', 'Executive car', 'Auto racing', 'Windshield', 'Alps', 'Gothic architecture', 'Road trip', 'Fan', 'Artifact', 'Lacustrine plain', 'Goggles', 'Tide', 'Museum', 'Baseball', 'Infantry', 'Cooking', 'Flower Arranging', 'Bride', 'Farmhouse', 'Fir', 'Blossom', 'Bicycles--Equipment and supplies', 'Appetizer', 'Seabird', 'Supercar', 'Houseplant', 'Eating', 'Barechested', 'Denim', 'Military camouflage', 'Winter storm', 'Rare breed (dog)', 'Retro style', 'Marsh', 'Butterfly', 'Non-commissioned officer', 'Rose family', 'Shelving', 'Bicycle handlebar', 'Cosplay', 'Auditorium', 'Reptile', 'Customer', 'Custom car', 'Massif', 'Zoo', 'Cycle sport', 'Engineering', 'Headland', 'Human foot', 'Duathlon', 'Transparent material', 'Bicycle tire', 'Metro', 'Silhouette', 'Diet food', 'Bla
# ...

# %%
# categories whose number exists in [2000, 3000)
category6 = [i for i, j in num_data if 2000 <= j < 3000]
len(category6)
# Out:
# 285

# %%
print(category6)
# Out:
# ['Neon', 'Vulnerable Native Breeds', 'Dome (Geology)', 'Baseball player', 'Gun', 'Mountain bike', 'Jazz club', 'Cyclo-cross bicycle', 'Horse supplies', 'Spruce', 'Resort', 'Grave', 'Freight transport', 'Half marathon', 'Bedroom', 'Bridal accessory', 'Marine mammal', 'Cross-country cycling', 'Seat of local government', 'Van', 'Dairy Product', 'Scene', 'Outdoor furniture', 'Line art', 'Convention center', 'Frozen dessert', 'Gluten', 'Wood flooring', 'Fen', 'Baseball park', 'Dishware', 'Plastic', 'Fender', 'Outdoor structure', 'Winter sport', 'Chocolate', 'Boardsport', 'College baseball', 'Portable communications device', 'Pattern (Fashion Design)', 'Bed', 'News conference', 'Laptop', 'Summit', 'North american fraternity and sorority housing', 'Convertible', 'Home appliance', 'Skyway', 'Larch', 'Brush-footed butterfly', 'Glacial landform', 'Acrylic paint', 'Klippe', 'Champagne stemware', 'Reef', 'Kitten', 'Home accessories', 'Baseball equipment', 'Bicycle saddle', 'Sports car racing', '
# ...

# %%
# categories whose number exists in [1500, 2000)
category7 = [i for i, j in num_data if 1500 <= j < 2000]
len(category7)
# Out:
# 244

# %%
print(category7)
# Out:
# ['Japanese cuisine', 'Baptistery', 'Course (Education)', 'Lagoon', 'Christmas lights', 'Fin', 'Vault', 'Countertop', 'Bell tower', 'Presidential palace', 'Makeover', 'Bed frame', 'Big cats', 'Fighter aircraft', 'Art exhibition', 'Hunting dog', 'Back', 'Bronze (Color)', 'Speedboat', 'Mountain river', 'Rodent', 'Label', 'Stick and Ball Games', 'Laminate flooring', 'Adventure racing', 'Basketball (Sport)', 'Barn', 'Kick (Sports)', 'Automotive mirror', 'Cook', 'Plywood', 'Levee', 'Camera operator', 'Off-roading', 'Windsports', 'Drummer', 'Paddle', 'Award ceremony', 'Groupset', 'Child model', 'Infielder', 'Baby toys', 'Emergency', 'Beetle', 'Bug', 'Shinto shrine', 'Compact sport utility vehicle', 'Wedding reception', 'Light commercial vehicle', 'Blue-collar worker', 'Non-vascular land plant', 'Hawker', 'Plush', 'Fish pond', 'Fan convention', 'Pc game', 'Single-lens reflex camera', 'Small appliance', "Kids' meal", 'Ritual', 'Cove', 'Rubble', 'Coral', 'Wine bottle', 'Colorfulness', 'Militar
# ...

# %%
# categories whose number exists in [1000, 1500)
category8 = [i for i, j in num_data if 1000 <= j < 1500]
len(category8)
# Out:
# 422

# %%
print(category8)
# Out:
# ['Batholith', 'Tattoo', 'Lizard', 'Tar', 'Australian mist', 'Liquid', 'Cheering', 'Composer', 'Elephant', 'Squirrel', 'Breakfast sandwich', 'Bob cut', 'Spring break', 'Basketball moves', 'Steamed rice', 'Porch', 'Bakery', 'Optical instrument', 'Teenage puppy love', 'Celestial event', 'Precipitation', 'Factory', 'Camellia', 'Liver (Color)', 'Library', 'Beanie', 'Airbus a320 family', 'Legume', 'Bridal party dress', 'Dining room', 'Prophet', 'Reading', 'Pumpkin', 'Retriever', 'Basketball (Ball)', 'Display window', 'China rose', 'Sink', 'Inflatable', 'Security lighting', 'Birthday', 'Birthday cake', 'Flea market', 'Compact van', 'Limestone', 'Sibling', 'Flag of the united states', 'Winter squash', 'Galliformes', 'Office supplies', 'Fair', 'Cupcake', 'Trailer truck', 'Holiday ornament', 'Steam engine', 'Sorrel (Color)', 'Arena football', 'Body jewelry', 'Crane (Machine)', 'Lighthouse', 'Air racing', 'Miniature', 'Ice rink', 'Calabaza', 'Tights', 'Picnic', 'Hub gear', 'Autocross', 'Flightl
# ...

# %%
# categories whose number exists in [500, 1000)
category9 = [i for i, j in num_data if 500 <= j < 1000]
len(category9)
# Out:
# 954

# %%
print(category9)
# Out:
# ['Owl', 'Malvales', 'Rice', 'Group A', 'Personal computer hardware', 'Clip art', 'College ice hockey', 'Jazz', 'Musical', 'Colonel', 'Concert dance', 'Lager', 'Project', 'Parachute', 'Rugby union', 'Varnish', 'Pizza cheese', 'Cylinder', 'Skull', 'Cucumber, gourd, and melon family', 'Canyon', 'Tennis Equipment', 'Wagon', 'Carbon', 'Petit four', 'Molluscs', 'Landscape lighting', 'Kayaking', 'Lymantria dispar dispar', 'Tennis court', 'Knit cap', 'Vase', 'Algae', 'Norwegian forest cat', 'Deck (Building)', 'Marshmallow creme', 'Naval ship', 'Motorcycle helmet', 'Pallone', 'Lion', 'Concept car', 'Videographer', 'Brochure', 'Public library', 'Ballroom', 'Piano', 'Snake', 'Stew', 'Scarf', 'Marsupial', 'Café au lait', 'Ristretto', 'Bicycle seatpost', 'Squash (Plant)', 'Rescue', 'Coraciiformes', 'Ancient rome', 'Braising', 'Cello', 'Shellfish', 'Business jet', 'Cactus', 'Waste', 'Wetsuit', 'Gardening', 'Volkswagen', 'Curb', 'Caffè americano', 'Gull', 'Carriage', 'Technician', 'Newsprint', 'Ska
# ...

# %%
# categories whose number exists in [200, 500)
categoryA = [i for i, j in num_data if 200 <= j < 500]
len(categoryA)
# Out:
# 1618

# %%
print(categoryA)
# Out:
# ['Roman temple', 'Martial arts', 'Telephone', 'Speedometer', 'Eumenidae', 'Snails and slugs', 'Wolf spider', 'Morkie', 'Derailleur gears', 'Cereal', 'Melon', 'Russian blue', 'Pray', 'Personal water craft', 'Training ship', 'Borador', 'Cutworms', 'Chain', 'Euryops pectinatus', 'Mixed martial arts', 'California sea lion', 'Ski binding', 'Touch football', 'Dandelion coffee', 'Pride parade', 'Mandarin orange', 'Fork', 'Obelisk', 'Professional wrestling', 'RV', 'Lamian', 'Poppy', 'Dairy (Business)', 'Common Dandelion', 'Flourless chocolate cake', "Women's football", 'Boeing 737 next generation', 'Boeing 757', 'Champagne', 'Sound engineer', 'Fireworks', 'Electronic engineering', 'Coloring book', 'Sock', 'Electrical wiring', 'Snowman', 'Display board', 'Demolition', 'Workwear', 'Satin', 'Twinjet', 'Penny bun', 'Weevil', 'Gazania', 'Bell peppers and chili peppers', 'Flash (Photography)', 'Rugby sevens', 'Folkrace', 'Wall clock', 'Shrimp', 'Sōmen', 'Great black-backed gull', 'Rib eye steak', 
# ...

# %%
# categories whose number exists in [100, 200)
categoryB = [i for i, j in num_data if 100 <= j < 200]
len(categoryB)
# Out:
# 1464

# %%
print(categoryB)
# Out:
# ['Volcanic plug', 'Cooktop', 'Greater flamingo', 'Beech', 'Okazu', 'Diamond', 'Canaan dog', 'Prunus spinosa', 'Basketball shoe', 'Minestrone', 'Logging', 'Pembroke welsh corgi', 'Batchoy', 'Rackets', 'Bakmi', 'Whole wheat bread', 'Artificial nails', 'Georgia pine', 'Oriental poppy', 'Python', 'Bulletin board', 'Hawaiian food', 'Porcupine', 'Pomeranian', 'Carpenter', 'Trip computer', 'Dhole', 'Lavandula dentata', 'Disabled sports', 'Martini glass', 'Ipoh white coffee', 'Bredele', 'Coast guard', 'Peddler', 'Jeongol', 'Bus stop', 'Abalone', 'Teddy roosevelt terrier', 'Potcake dog', 'Air-raid shelter', 'Gratin', 'Fishing rod', 'Webbing clothes moth', 'Beach volleyball', 'Orange juice', 'Window valance', 'Gonimbrasia belina', "Father's day", 'Hyundai', 'Water bottle', 'Smartweed-buckwheat family', 'Mechanic', 'Cdj', 'Tree frog', 'Chocolate truffle', 'Hendl', 'Colorpoint shorthair', 'Medal', 'Viceroy (butterfly)', 'Suede', 'Snow removal', 'Saxhorn', 'Glanville fritillary', 'Bolognese', 'Te
# ...

# %% [markdown]
# ### Select Data Subset

# %%
# data_subset1 = data_set.filter_by(category1, 'DisplayName')
# data_subset2 = data_set.filter_by(category2, 'DisplayName')
# data_subset3 = data_set.filter_by(category3, 'DisplayName')
# data_subset4 = data_set.filter_by(category4, 'DisplayName')
# data_subset5 = data_set.filter_by(category5, 'DisplayName')
# data_subset6 = data_set.filter_by(category6, 'DisplayName')
# data_subset7 = data_set.filter_by(category7, 'DisplayName')
# data_subset8 = data_set.filter_by(category8, 'DisplayName')
# data_subset9 = data_set.filter_by(category9, 'DisplayName')
# data_subsetA = data_set.filter_by(categoryA, 'DisplayName')
# data_subsetB = data_set.filter_by(categoryB, 'DisplayName')

# %% [markdown]
# ### Split category for balancing

# %% [markdown]
# ##### 카테고리1의 전체 데이터로 할 때 속도도 느리고 성능이 낮음

# %%
data_subset1
# Out:
# Columns:
# 	ImageID	str
# 	deep_features	array
# 	DisplayName	str
#
# Rows: 12490323
#
# Data:
# +------------------+-------------------------------+--------------+
# |     ImageID      |         deep_features         | DisplayName  |
# +------------------+-------------------------------+--------------+
# | 000002b66c9c498e | [0.25520071387290955, 0.0,... |    Event     |
# | 000002b66c9c498e | [0.25520071387290955, 0.0,... |  Community   |
# | 000002b97e5471a0 | [0.42842113971710205, 0.0,... |     Wall     |
# | 000002b97e5471a0 | [0.42842113971710205, 0.0,... | Real estate  |
# | 000002b97e5471a0 | [0.42842113971710205, 0.0,... |   Daytime    |
# | 000002b97e5471a0 | [0.42842113971710205, 0.0,... |     Sky      |
# | 000002b97e5471a0 | [0.42842113971710205, 0.0,... |    Facade    |
# | 000002b97e5471a0 | [0.42842113971710205, 0.0,... | Architecture |
# | 000002b97e5471a0 | [0.42842113971710205, 0.0,... |   Property   |
# ...

# %% [markdown]
# # model1_e12490323_i200

# %% [markdown]
# ### Modeling

# %%
# %time model = tc.image_classifier.create(data_subset1, feature='deep_features', target='DisplayName', max_iterations=200, batch_size=64, validation_set=None) # , model='squeezenet_v1.1'', solver='lbfgs'

# %% [markdown]
# ### Save Model

# %%
model.save('model1_12490323.model')

# %%
model1 = tc.load_model('model1.model')

# %%
model1
# Out:
# Class                                    : ImageClassifier
#
# Schema
# ------
# Number of classes                        : 72
# Number of feature columns                : 1
# Input image shape                        : (3, 224, 224)
#
# Training summary
# ----------------
# Number of examples                       : 12490323
# Training loss                            : 42959538.2651
# Training time (sec)                      : 14581.0741

# %% [markdown]
# ## Data sampling for fast learning
# - 샘플데이터로 성능 올리기
# - 레이블에 비해 매우 많은 데이터로 샘플링 작업 수행

# %% [markdown]
# # model1_e12490323_i200

# %% [markdown]
# ###### category1

# %%
data_sampleset1 = data_subset1.sample(.1)
data_sampleset1
# Out:
# Columns:
# 	ImageID	str
# 	deep_features	array
# 	DisplayName	str
#
# Rows: Unknown
#
# Data:
# +------------------+-------------------------------+--------------+
# |     ImageID      |         deep_features         | DisplayName  |
# +------------------+-------------------------------+--------------+
# | 000002b97e5471a0 | [0.42842113971710205, 0.0,... |     Sky      |
# | 0000048549557964 | [0.3832293152809143, 0.0, ... | Land vehicle |
# | 0000048549557964 | [0.3832293152809143, 0.0, ... |  Urban area  |
# | 000004f4400f6ec5 | [0.17075125873088837, 0.0,... |    Human     |
# | 000004f4400f6ec5 | [0.17075125873088837, 0.0,... |    Beauty    |
# | 000018acd19b4ad3 | [0.19296137988567352, 0.0,... |    Beauty    |
# | 00001bc2c4027449 | [0.6756594777107239, 0.0, ... |    Nature    |
# | 0000201cd362f303 | [0.11061318218708038, 0.0,... |    Light     |
# | 0000253ea4ecbf19 | [0.05608966946601868, 0.0,... |    Black     |
# ...

# %%
model1 = tc.image_classifier.create(data_sampleset1, feature='deep_features', target='DisplayName', max_iterations=500, batch_size=128, validation_set=None)

# %%
data_sampleset1_ = data_subset1.sample(.05)
data_sampleset1_
# Out:
# Columns:
# 	ImageID	str
# 	deep_features	array
# 	DisplayName	str
#
# Rows: Unknown
#
# Data:
# +------------------+-------------------------------+-------------+
# |     ImageID      |         deep_features         | DisplayName |
# +------------------+-------------------------------+-------------+
# | 0000048549557964 | [0.3832293152809143, 0.0, ... |     Wall    |
# | 000004f4400f6ec5 | [0.17075125873088837, 0.0,... | Interaction |
# | 000004f4400f6ec5 | [0.17075125873088837, 0.0,... | Male person |
# | 000004f4400f6ec5 | [0.17075125873088837, 0.0,... |   Lighting  |
# | 000013ba71c12506 | [0.7567945122718811, 0.0, ... |    Black    |
# | 000020780ccee28d | [0.031676121056079865, 0.0... |     Room    |
# | 000025ea48cab6fc | [0.3798547387123108, 0.0, ... |   Morning   |
# | 0000271195f2c007 | [0.017519637942314148, 0.0... |    Black    |
# | 0000339d0372e7e6 | [0.23057964444160461, 0.0,... |     Line    |
# | 0000375a83c19042 | [0.36390140652656555, 0.0,... |    Biome    |
# ...

# %%
model1_ = tc.image_classifier.create(data_sampleset1, feature='deep_features', target='DisplayName', max_iterations=100, batch_size=128, validation_set=None)

# %% [markdown]
# # model2_e765634_i70

# %% [markdown]
# ###### category2

# %%
data_subset2 = data_set.filter_by(category2, 'DisplayName')

# %%
data_subset2 = data_subset2.sample(.1)

# %%
# %time model2 = tc.image_classifier.create(data_subset2, feature='deep_features', target='DisplayName', max_iterations=70, batch_size=64, validation_set=None) # , model='squeezenet_v1.1'', solver='lbfgs'

# %%
model2.save('model2_e765634_i70')

# %%
# %time model2 = tc.image_classifier.create(data_subset2, feature='deep_features', target='DisplayName', max_iterations=150, batch_size=128, validation_set=None) # , model='squeezenet_v1.1'', solver='lbfgs'

# %%
model2

# %% [markdown]
# # model3_e485637_i150

# %% [markdown]
# ###### category3

# %%
data_subset3 = data_set.filter_by(category3, 'DisplayName')
data_subset3 = data_subset3.sample(.1)

# %%
data_subset3
# Out:
# Columns:
# 	ImageID	str
# 	deep_features	array
# 	DisplayName	str
#
# Rows: 485637
#
# Data:
# +------------------+-------------------------------+--------------------+
# |     ImageID      |         deep_features         |    DisplayName     |
# +------------------+-------------------------------+--------------------+
# | 0000201cd362f303 | [0.11061318218708038, 0.0,... |      Audience      |
# | 00002f4ff380c64c | [0.8477177023887634, 0.0, ... |      Walkway       |
# | 0000313e5dccf13b | [0.16881220042705536, 0.0,... | Turquoise (Color)  |
# | 00003e7c13af160c | [0.526064395904541, 0.0, 0... |        Lawn        |
# | 00004668fd1ee4e7 | [0.02332286536693573, 0.0,... |     Plantation     |
# | 00004fd8760d4346 | [0.5507038831710815, 0.0, ... | Aerial photography |
# | 00005903203677bc | [0.07798346877098083, 0.0,... | Terrestrial animal |
# | 00005e7429a94ad4 | [0.05762740224599838, 0.0,... |      Painting      |
# ...

# %%
# %time model3 = tc.image_classifier.create(data_subset3, feature='deep_features', target='DisplayName', max_iterations=150, batch_size=64, validation_set=None) # , model='squeezenet_v1.1'', solver='lbfgs'

# %%
model3.save('model3_e485637_i150')

# %% [markdown]
# # model4_e204178_i150

# %% [markdown]
# ###### category4

# %%
data_subset4 = data_set.filter_by(category4, 'DisplayName')
data_subset4 = data_subset4.sample(.1)
# %time model4 = tc.image_classifier.create(data_subset4, feature='deep_features', target='DisplayName', max_iterations=150, batch_size=64, validation_set=None) # , model='squeezenet_v1.1'', solver='lbfgs'

# %%
model4.save('model4_e204178_i150')

# %% [markdown]
# # model5_e115711_i150

# %% [markdown]
# ###### category5

# %%
data_subset5 = data_set.filter_by(category5, 'DisplayName')
data_subset5 = data_subset5.sample(.1)
# %time model5 = tc.image_classifier.create(data_subset5, feature='deep_features', target='DisplayName', max_iterations=150, batch_size=64, validation_set=None) # , model='squeezenet_v1.1'', solver='lbfgs'

# %%
model5.save('model5_e115711_i150')

# %% [markdown]
# # model6_e69675_i150

# %% [markdown]
# ###### category6

# %%
data_subset6 = data_set.filter_by(category6, 'DisplayName')
data_subset6 = data_subset6.sample(.1)
# %time model6 = tc.image_classifier.create(data_subset6, feature='deep_features', target='DisplayName', max_iterations=150, batch_size=64, validation_set=None) # , model='squeezenet_v1.1'', solver='lbfgs'

# %%
model6.save('model6_e69675_i150')

# %% [markdown]
# # model7

# %% [markdown]
# ###### category7

# %%
data_subset7 = data_set.filter_by(category7, 'DisplayName')
data_subset7 = data_subset7.sample(.1)
# %time model7 = tc.image_classifier.create(data_subset7, feature='deep_features', target='DisplayName', max_iterations=150, batch_size=64, validation_set=None) # , model='squeezenet_v1.1'', solver='lbfgs'

# %%
model7.save('model7_e41970_i150')

# %% [markdown]
# # model8

# %% [markdown]
# ###### category8

# %%
data_subset8 = data_set.filter_by(category8, 'DisplayName')
data_subset8 = data_subset8.sample(.1)
# %time model8 = tc.image_classifier.create(data_subset8, feature='deep_features', target='DisplayName', max_iterations=150, batch_size=64, validation_set=None) # , model='squeezenet_v1.1'', solver='lbfgs'

# %%
model8.save('model8_e51424_i150')

# %% [markdown]
# # model9

# %% [markdown]
# ###### category9

# %%
data_subset9 = data_set.filter_by(category9, 'DisplayName')
data_subset9 = data_subset9.sample(.1)
# %time model9 = tc.image_classifier.create(data_subset9, feature='deep_features', target='DisplayName', max_iterations=150, batch_size=64, validation_set=None) # , model='squeezenet_v1.1'', solver='lbfgs'

# %%
model9.save('model9_e67986_i150')

# %% [markdown]
# # modelA

# %% [markdown]
# ###### categoryA

# %%
data_subsetA = data_set.filter_by(categoryA, 'DisplayName')
data_subsetA = data_subsetA.sample(.1)
# %time modelA = tc.image_classifier.create(data_subsetA, feature='deep_features', target='DisplayName', max_iterations=150, batch_size=64, validation_set=None) # , model='squeezenet_v1.1'', solver='lbfgs'

# %%
modelA.save('modelA_')

# %% [markdown]
# # modelB

# %% [markdown]
# ###### categoryB

# %% [markdown]
# ## 데이터 사이즈, 이터레이션 튜닝

# %% [markdown]
# ### 이터레이션 조절

# %%
data_subsetB = data_set.filter_by(categoryB, 'DisplayName')
# data_subsetB = data_subsetB.sample(.1)
# %time modelB = tc.image_classifier.create(data_subsetB, feature='deep_features', target='DisplayName', max_iterations=150, batch_size=64, validation_set=None) # , model='squeezenet_v1.1'', solver='lbfgs'

# %%
modelB.save('modelB_')

# %%
data_subsetB = data_set.filter_by(categoryB, 'DisplayName')
# data_subsetB = data_subsetB.sample(.1)
# %time modelB_ = tc.image_classifier.create(data_subsetB, feature='deep_features', target='DisplayName', max_iterations=150, batch_size=64, validation_set=None) # , model='squeezenet_v1.1'', solver='lbfgs'

# %%
modelB_.save('modelB_full')

# %% [markdown]
# # model5_e115871_i300

# %%
data_subset5 = data_set.filter_by(category5, 'DisplayName')
data_subset5 = data_subset5.sample(.1)
# %time model5 = tc.image_classifier.create(data_subset5, feature='deep_features', target='DisplayName', max_iterations=300, batch_size=64, validation_set=None) # , model='squeezenet_v1.1'', solver='lbfgs'

# %%
model5.save('model5_e115871_i300')

# %% [markdown]
# ##### 너무 큰 데이터 샘플수 조절

# %% [markdown]
# # model1_e62670_i150

# %%
data_subset1 = data_set.filter_by(category1, 'DisplayName')
data_subset1 = data_subset1.sample(.005)
# %time model1 = tc.image_classifier.create(data_subset1, feature='deep_features', target='DisplayName', max_iterations=150, batch_size=64, validation_set=None) # , model='squeezenet_v1.1'', solver='lbfgs'

# %%
model1.save('model1_e62670_i150')

# %%
data_subset1 = data_set.filter_by(category1, 'DisplayName')
data_subset1 = data_subset1.sample(.01)
# %time model1 = tc.image_classifier.create(data_subset1, feature='deep_features', target='DisplayName', max_iterations=300, batch_size=64, validation_set=None) # , model='squeezenet_v1.1'', solver='lbfgs'

# %% [markdown]
# # model4

# %%
data_subset4 = data_set.filter_by(category4, 'DisplayName')
data_subset4 = data_subset4.sample(.05)
# %time model4 = tc.image_classifier.create(data_subset4, feature='deep_features', target='DisplayName', max_iterations=150, batch_size=64, validation_set=None) # , model='squeezenet_v1.1'', solver='lbfgs'

# %% [markdown]
# ### extra

# %%
data_subset6 = data_set.filter_by(category6, 'DisplayName')
data_subset6 = data_subset6.sample(.1)
# %time model6 = tc.image_classifier.create(data_subset6, feature='deep_features', target='DisplayName', max_iterations=70, batch_size=64, validation_set=None) # , model='squeezenet_v1.1'', solver='lbfgs'

# %%
data_subset7 = data_set.filter_by(category7, 'DisplayName')
data_subset7 = data_subset7.sample(.1)
# %time model7 = tc.image_classifier.create(data_subset7, feature='deep_features', target='DisplayName', max_iterations=70, batch_size=64, validation_set=None) # , model='squeezenet_v1.1'', solver='lbfgs'

# %%
data_subset8 = data_set.filter_by(category8, 'DisplayName')
data_subset8 = data_subset8.sample(.1)
# %time model8 = tc.image_classifier.create(data_subset8, feature='deep_features', target='DisplayName', max_iterations=70, batch_size=64, validation_set=None) # , model='squeezenet_v1.1'', solver='lbfgs'

# %%
data_subset9 = data_set.filter_by(category9, 'DisplayName')
data_subset9 = data_subset9.sample(.1)
# %time model9 = tc.image_classifier.create(data_subset9, feature='deep_features', target='DisplayName', max_iterations=70, batch_size=64, validation_set=None) # , model='squeezenet_v1.1'', solver='lbfgs'

# %% [markdown]
# # balaced sampling data

# %%
data_set = tc.load_sframe('ClassificationDataset.sframe/')

# %%
data_set
# Out:
# Columns:
# 	ImageID	str
# 	deep_features	array
# 	DisplayName	str
#
# Rows: 33065804
#
# Data:
# +------------------+-------------------------------+-----------------+
# |     ImageID      |         deep_features         |   DisplayName   |
# +------------------+-------------------------------+-----------------+
# | 000002b66c9c498e | [0.25520071387290955, 0.0,... |     Birthday    |
# | 000002b66c9c498e | [0.25520071387290955, 0.0,... |    Friendship   |
# | 000002b66c9c498e | [0.25520071387290955, 0.0,... |     Cuisine     |
# | 000002b66c9c498e | [0.25520071387290955, 0.0,... |      Event      |
# | 000002b66c9c498e | [0.25520071387290955, 0.0,... |      Torte      |
# | 000002b66c9c498e | [0.25520071387290955, 0.0,... | Cake decorating |
# | 000002b66c9c498e | [0.25520071387290955, 0.0,... |   Anniversary   |
# | 000002b66c9c498e | [0.25520071387290955, 0.0,... |      Party      |
# | 000002b66c9c498e | [0.25520071387290955, 0.0,... |    Community    |
# ...

# %%
num_data = Counter(data_set['DisplayName'])
num_data = num_data.items()
num_data = sorted(num_data, key=lambda x: x[1], reverse=True)

# %%
# categories whose number exists in [100000, 300000)
category1 = [i for i, j in num_data if 100000 <= j < 300000]
len(category1)
# Out:
# 72

# %%
data_subset1 = data_set.filter_by(category1, 'DisplayName')

# %%
data_subset1
# Out:
# Columns:
# 	ImageID	str
# 	deep_features	array
# 	DisplayName	str
#
# Rows: 12490323
#
# Data:
# +------------------+-------------------------------+--------------+
# |     ImageID      |         deep_features         | DisplayName  |
# +------------------+-------------------------------+--------------+
# | 000002b66c9c498e | [0.25520071387290955, 0.0,... |    Event     |
# | 000002b66c9c498e | [0.25520071387290955, 0.0,... |  Community   |
# | 000002b97e5471a0 | [0.42842113971710205, 0.0,... |     Wall     |
# | 000002b97e5471a0 | [0.42842113971710205, 0.0,... | Real estate  |
# | 000002b97e5471a0 | [0.42842113971710205, 0.0,... |   Daytime    |
# | 000002b97e5471a0 | [0.42842113971710205, 0.0,... |     Sky      |
# | 000002b97e5471a0 | [0.42842113971710205, 0.0,... |    Facade    |
# | 000002b97e5471a0 | [0.42842113971710205, 0.0,... | Architecture |
# | 000002b97e5471a0 | [0.42842113971710205, 0.0,... |   Property   |
# ...

# %%
data_sampled = data_subset1.sample(0.05)

# %%
data_sampled.materialize()

# %%
data_sampled
# Out:
# Columns:
# 	ImageID	str
# 	deep_features	array
# 	DisplayName	str
#
# Rows: 623933
#
# Data:
# +------------------+-------------------------------+--------------+
# |     ImageID      |         deep_features         | DisplayName  |
# +------------------+-------------------------------+--------------+
# | 0000071d71a0a6f6 | [0.08740587532520294, 0.0,... |    Event     |
# | 000013ba71c12506 | [0.7567945122718811, 0.0, ... |    White     |
# | 00001bc2c4027449 | [0.6756594777107239, 0.0, ... |    Beauty    |
# | 0000201cd362f303 | [0.11061318218708038, 0.0,... |    Light     |
# | 000020780ccee28d | [0.031676121056079865, 0.0... |    Green     |
# | 000020780ccee28d | [0.031676121056079865, 0.0... |     Line     |
# | 0000253ea4ecbf19 | [0.05608966946601868, 0.0,... |    White     |
# | 000025ea48cab6fc | [0.3798547387123108, 0.0, ... |    Human     |
# | 00002f4ff380c64c | [0.8477177023887634, 0.0, ... | Public space |
# ...

# %%
df_sample = data_sampleset[['DisplayName']].to_dataframe()

# %%
from turicreate import aggregate as agg
count_data = data_sampleset.groupby('DisplayName', operations={'count': agg.COUNT()})

# %%
count_data['count']
# Out:
# dtype: int
# Rows: 72
# [7133, 9837, 7953, 8770, 5381, 6714, 5403, 7609, 13148, 8031, 9004, 10534, 11225, 8899, 6251, 6711, 7888, 11529, 8876, 4924, 10638, 9195, 6192, 6487, 6954, 13324, 12789, 7015, 12136, 11413, 7549, 6500, 5052, 11110, 7890, 11854, 6488, 8973, 7002, 9594, 5353, 5200, 12918, 12207, 8986, 6060, 7578, 7169, 7466, 14262, 5112, 7197, 13036, 10593, 10818, 10618, 5752, 8414, 6321, 12895, 7253, 5324, 7537, 13967, 9030, 6445, 7559, 10652, 10631, 5092, 5563, 12950]

# %%
data_sampleset
# Out:
# Columns:
# 	ImageID	str
# 	deep_features	array
# 	DisplayName	str
#
# Rows: 623933
#
# Data:
# +------------------+-------------------------------+--------------+
# |     ImageID      |         deep_features         | DisplayName  |
# +------------------+-------------------------------+--------------+
# | 0000071d71a0a6f6 | [0.08740587532520294, 0.0,... |    Event     |
# | 000013ba71c12506 | [0.7567945122718811, 0.0, ... |    White     |
# | 00001bc2c4027449 | [0.6756594777107239, 0.0, ... |    Beauty    |
# | 0000201cd362f303 | [0.11061318218708038, 0.0,... |    Light     |
# | 000020780ccee28d | [0.031676121056079865, 0.0... |    Green     |
# | 000020780ccee28d | [0.031676121056079865, 0.0... |     Line     |
# | 0000253ea4ecbf19 | [0.05608966946601868, 0.0,... |    White     |
# | 000025ea48cab6fc | [0.3798547387123108, 0.0, ... |    Human     |
# | 00002f4ff380c64c | [0.8477177023887634, 0.0, ... | Public space |
# ...

# %%
# %time model1_e623933 = tc.image_classifier.create(data_sampleset, feature='deep_features', target='DisplayName', max_iterations=150, batch_size=64, validation_set=None) # , model='squeezenet_v1.1'', solver='lbfgs'

# %%
model1_e623933.save('model1_e623933_i150')

# %%
# %time model1_e623933_i1500 = tc.image_classifier.create(data_sampleset, feature='deep_features', target='DisplayName', max_iterations=1500, batch_size=256, validation_set=None) # , model='squeezenet_v1.1'', solver='lbfgs'

# %%
model1_e623933_i1500.save('model1_e623933_i1500')

# %% [markdown]
# ### sample size 0.01

# %%
data_sampled_ = data_subset1.sample(0.01)

# %%
data_sampled_.materialize()

# %%
data_sampled_
# Out:
# Columns:
# 	ImageID	str
# 	deep_features	array
# 	DisplayName	str
#
# Rows: 623933
#
# Data:
# +------------------+-------------------------------+--------------+
# |     ImageID      |         deep_features         | DisplayName  |
# +------------------+-------------------------------+--------------+
# | 0000071d71a0a6f6 | [0.08740587532520294, 0.0,... |    Event     |
# | 000013ba71c12506 | [0.7567945122718811, 0.0, ... |    White     |
# | 00001bc2c4027449 | [0.6756594777107239, 0.0, ... |    Beauty    |
# | 0000201cd362f303 | [0.11061318218708038, 0.0,... |    Light     |
# | 000020780ccee28d | [0.031676121056079865, 0.0... |    Green     |
# | 000020780ccee28d | [0.031676121056079865, 0.0... |     Line     |
# | 0000253ea4ecbf19 | [0.05608966946601868, 0.0,... |    White     |
# | 000025ea48cab6fc | [0.3798547387123108, 0.0, ... |    Human     |
# | 00002f4ff380c64c | [0.8477177023887634, 0.0, ... | Public space |
# ...

# %%
from turicreate import aggregate as agg
count_data = data_sampled_.groupby('DisplayName', operations={'count': agg.COUNT()})

# %%
count_data['count']
# Out:
# dtype: int
# Rows: 72
# [7133, 9837, 7953, 8770, 5381, 6714, 5403, 7609, 13148, 8031, 9004, 10534, 11225, 8899, 6251, 6711, 7888, 11529, 8876, 4924, 10638, 9195, 6192, 6487, 6954, 13324, 12789, 7015, 12136, 11413, 7549, 6500, 5052, 11110, 7890, 11854, 6488, 8973, 7002, 9594, 5353, 5200, 12918, 12207, 8986, 6060, 7578, 7169, 7466, 14262, 5112, 7197, 13036, 10593, 10818, 10618, 5752, 8414, 6321, 12895, 7253, 5324, 7537, 13967, 9030, 6445, 7559, 10652, 10631, 5092, 5563, 12950]

# %%
data_sampled_
# Out:
# Columns:
# 	ImageID	str
# 	deep_features	array
# 	DisplayName	str
#
# Rows: 623933
#
# Data:
# +------------------+-------------------------------+--------------+
# |     ImageID      |         deep_features         | DisplayName  |
# +------------------+-------------------------------+--------------+
# | 0000071d71a0a6f6 | [0.08740587532520294, 0.0,... |    Event     |
# | 000013ba71c12506 | [0.7567945122718811, 0.0, ... |    White     |
# | 00001bc2c4027449 | [0.6756594777107239, 0.0, ... |    Beauty    |
# | 0000201cd362f303 | [0.11061318218708038, 0.0,... |    Light     |
# | 000020780ccee28d | [0.031676121056079865, 0.0... |    Green     |
# | 000020780ccee28d | [0.031676121056079865, 0.0... |     Line     |
# | 0000253ea4ecbf19 | [0.05608966946601868, 0.0,... |    White     |
# | 000025ea48cab6fc | [0.3798547387123108, 0.0, ... |    Human     |
# | 00002f4ff380c64c | [0.8477177023887634, 0.0, ... | Public space |
# ...

# %%
# %time model1_e623933 = tc.image_classifier.create(data_sampled_, feature='deep_features', target='DisplayName', max_iterations=150, batch_size=64, validation_set=None) # , model='squeezenet_v1.1'', solver='lbfgs'
# Out:
# Logistic regression:
# --------------------------------------------------------
# Number of examples          : 623933
# Number of classes           : 72
# Number of feature columns   : 1
# Number of unpacked features : 2048
# Number of coefficients      : 145479
# Starting L-BFGS
# --------------------------------------------------------
# +-----------+----------+-----------+--------------+-------------------+
# | Iteration | Passes   | Step size | Elapsed Time | Training Accuracy |
# +-----------+----------+-----------+--------------+-------------------+
# | 0         | 3        | 0.500000  | 87.691116    | 0.030162          |

# %% [markdown]
# ### Split Data Set Into Train and Test Set

# %%
train_data, test_data = data_set.random_split(0.9)

# %%
# %time model = tc.image_classifier.create(train_data, feature='deep_features', target='DisplayName', max_iterations=50, validation_set=None) # , model='squeezenet_v1.1'', solver='lbfgs'
# Out:
# Logistic regression:
# --------------------------------------------------------
# Number of examples          : 29760281
# Number of classes           : 14059
# Number of feature columns   : 1
# Number of unpacked features : 2048
# Number of coefficients      : 28804842
# Starting L-BFGS
# --------------------------------------------------------
# +-----------+----------+-----------+--------------+-------------------+
# | Iteration | Passes   | Step size | Elapsed Time | Training Accuracy |
# +-----------+----------+-----------+--------------+-------------------+

# %% [markdown]
# ### For Script

# %%
import turicreate as tc

# %%
img_fts = tc.SFrame('./Img_features_sframe/')

# %%
Mlabel = tc.SFrame('./Mlabel_sframe/')
# Mlabel

# %%
ImageInfo = tc.SFrame('./Img_Info_sframe/')
# ImageInfo

# %%
data_available = Mlabel.filter_by(img_fts['ImageID'], 'ImageID')
# to test

# %%
data_available = data_available[['ImageID', 'DisplayName']]

# %%
data_available = data_available.unstack('DisplayName', new_column_name='DisplayNames')

# %%
data_set = data_available.join(img_fts, on='ImageID')

# %%
data_set.materialize()

# %%
data_set = data_set.stack('DisplayNames', new_column_name='DisplayName')

# %%
# %time model = tc.image_classifier.create(data_set, feature='deep_features', target='DisplayName', max_iterations=200, validation_set=None) # , model='squeezenet_v1.1'', solver='lbfgs'
# Out:
# Logistic regression:
# --------------------------------------------------------
# Number of examples          : 29760281
# Number of classes           : 14059
# Number of feature columns   : 1
# Number of unpacked features : 2048
# Number of coefficients      : 28804842
# Starting L-BFGS
# --------------------------------------------------------
# +-----------+----------+-----------+--------------+-------------------+
# | Iteration | Passes   | Step size | Elapsed Time | Training Accuracy |
# +-----------+----------+-----------+--------------+-------------------+

# %% [markdown]
# ### Appendix

# %% [markdown]
# ### Pre-processing

# %%
img_fts = tc.SFrame('./Img_features_sframe/')

# %%
Mlabel = tc.SFrame('./Mlabel_sframe/')
# Mlabel

# %%
ImageInfo = tc.SFrame('./Img_Info_sframe/')
# ImageInfo

# %%
data_available = Mlabel.filter_by(img_fts['ImageID'], 'ImageID')
# to test

# %%
len(data_available)
# Out:
# 33065804

# %%
data_available
# Out:
# Columns:
# 	ImageID	str
# 	Source	str
# 	LabelName	str
# 	Confidence	float
# 	DisplayName	str
#
# Rows: 33065804
#
# Data:
# +------------------+---------+------------+------------+-----------------+
# |     ImageID      |  Source | LabelName  | Confidence |   DisplayName   |
# +------------------+---------+------------+------------+-----------------+
# | 000002b66c9c498e | machine | /m/01kcnl  |  0.777934  |     Birthday    |
# | 000002b66c9c498e | machine | /m/019_nn  |  0.622101  |    Friendship   |
# | 000002b66c9c498e | machine |  /m/01ykh  |  0.702814  |     Cuisine     |
# | 000002b66c9c498e | machine | /m/081pkj  |  0.734245  |      Event      |
# | 000002b66c9c498e | machine | /m/026pc7x |  0.876484  |      Torte      |
# | 000002b66c9c498e | machine | /m/02r_57s |  0.713151  | Cake decorating |
# | 000002b66c9c498e | machine | /m/02f6b9  |  0.649561  |   Anniversary   |
# | 000002b66c9c498e | machine |  /m/05_4_  |  0.763208  |      Party      |
# ...

# %%
data_available = data_available[['ImageID', 'DisplayName']]

# %%
data_available = data_available.unstack('DisplayName', new_column_name='DisplayNames')

# %%
data_available
# Out:
# Columns:
# 	ImageID	str
# 	DisplayNames	list
#
# Rows: 1741091
#
# Data:
# +------------------+-------------------------------+
# |     ImageID      |          DisplayNames         |
# +------------------+-------------------------------+
# | 32ab4c44b81849ff | [Petal, Close-up, Pedicel,... |
# | dde2cd71f457a9a3 | [Textile, Visual arts, Art... |
# | af628b2630c93d64 | [Transport, Plant, Wildern... |
# | 6f4ad4df7339a628 | [Rural area, Tree, Geology... |
# | 2fd6052726ebe5f1 | [Ball game, Six-man footba... |
# | 43d4904f960c9f17 | [Tan, Cameras & optics, Le... |
# | b07a5a3bcd534ee5 |            [Person]           |
# | c4f8ea8a0e612b37 | [Nature, Wilderness, Wood,... |
# | e3529bd372f19493 | [Body of water, Sailboat, ... |
# | 283f343752daa6a6 | [Association, Gentleman, H... |
# +------------------+-------------------------------+
# [1741091 rows x 2 columns]
# Note: Only the head of the SFrame is printed.
# ...

# %%
# img_fts = img_fts.unpack('deep_features')

# %%
# img_fts
# Out:
# Columns:
# 	ImageID	str
# 	deep_features.0	float
# 	deep_features.1	float
# 	deep_features.2	float
# 	deep_features.3	float
# 	deep_features.4	float
# 	deep_features.5	float
# 	deep_features.6	float
# 	deep_features.7	float
# 	deep_features.8	float
# 	deep_features.9	float
# 	deep_features.10	float
# 	deep_features.11	float
# 	deep_features.12	float
# 	deep_features.13	float
# 	deep_features.14	float
# 	deep_features.15	float
# 	deep_features.16	float
# 	deep_features.17	float
# 	deep_features.18	float
# 	deep_features.19	float
# 	deep_features.20	float
# 	deep_features.21	float
# 	deep_features.22	float
# 	deep_features.23	float
# 	deep_features.24	float
# 	deep_features.25	float
# 	deep_features.26	float
# 	deep_features.27	float
# 	deep_features.28	float
# 	deep_features.29	float
# 	deep_features.30	float
# 	deep_features.31	float
# 	deep_features.32	float
# 	deep_features.33	float
# 	deep_features.34	float
# 	deep_features.35	float
# 	deep_features.36	float
# ...

# %%
data_set = data_available.join(img_fts, on='ImageID')

# %%
data_set
# Out:
# Columns:
# 	ImageID	str
# 	deep_features.0	float
# 	deep_features.1	float
# 	deep_features.2	float
# 	deep_features.3	float
# 	deep_features.4	float
# 	deep_features.5	float
# 	deep_features.6	float
# 	deep_features.7	float
# 	deep_features.8	float
# 	deep_features.9	float
# 	deep_features.10	float
# 	deep_features.11	float
# 	deep_features.12	float
# 	deep_features.13	float
# 	deep_features.14	float
# 	deep_features.15	float
# 	deep_features.16	float
# 	deep_features.17	float
# 	deep_features.18	float
# 	deep_features.19	float
# 	deep_features.20	float
# 	deep_features.21	float
# 	deep_features.22	float
# 	deep_features.23	float
# 	deep_features.24	float
# 	deep_features.25	float
# 	deep_features.26	float
# 	deep_features.27	float
# 	deep_features.28	float
# 	deep_features.29	float
# 	deep_features.30	float
# 	deep_features.31	float
# 	deep_features.32	float
# 	deep_features.33	float
# 	deep_features.34	float
# 	deep_features.35	float
# 	deep_features.36	float
# ...

# %%
data_set.materialize()

# %%
data_set = data_set.stack('DisplayNames', new_column_name='DisplayName')

# %%
data_set
# Out:
# Columns:
# 	ImageID	str
# 	deep_features	array
# 	DisplayName	str
#
# Rows: 6621768
#
# Data:
# +------------------+-------------------------------+------------------------+
# |     ImageID      |         deep_features         |      DisplayName       |
# +------------------+-------------------------------+------------------------+
# | 000002b97e5471a0 | [0.42842113971710205, 0.0,... |          Wall          |
# | 000002b97e5471a0 | [0.42842113971710205, 0.0,... |      Real estate       |
# | 000002b97e5471a0 | [0.42842113971710205, 0.0,... |        Daytime         |
# | 000002b97e5471a0 | [0.42842113971710205, 0.0,... | Brutalist architecture |
# | 000002b97e5471a0 | [0.42842113971710205, 0.0,... |          Sky           |
# | 000002b97e5471a0 | [0.42842113971710205, 0.0,... |         Facade         |
# | 000002b97e5471a0 | [0.42842113971710205, 0.0,... |      Architecture      |
# | 000002b97e5471a0 | [0.42842113971710205, 0.0,... |        Property        |
# ...

# %%
# data_set.save('ClassificationDataset.sframe')

# %% [markdown]
# ### K-fold validation

# %%
# # k-fold
# size_kfold = int(len(data_available)/5)
# data_available = data_available[:size_kfold]
# size_kfold
# Out:
# 348218

# %%
# test data
test_data = data_available[:1000000]
test_data = test_data[['ImageID', 'DisplayName']]
test_data = test_data.unstack('DisplayName', new_column_name='DisplayNames')
test_data = img_fts.join(test_data, on='ImageID')

# %%
test_data
# Out:
# Columns:
# 	ImageID	str
# 	deep_features	array
# 	DisplayNames	list
#
# Rows: 54791
#
# Data:
# +------------------+-------------------------------+
# |     ImageID      |         deep_features         |
# +------------------+-------------------------------+
# | 000002b66c9c498e | [0.25520071387290955, 0.0,... |
# | 000002b97e5471a0 | [0.42842113971710205, 0.0,... |
# | 000002c707c9895e | [0.2287079095840454, 0.0, ... |
# | 0000048549557964 | [0.3832293152809143, 0.0, ... |
# | 000004f4400f6ec5 | [0.17075125873088837, 0.0,... |
# | 0000071d71a0a6f6 | [0.08740587532520294, 0.0,... |
# | 000013ba71c12506 | [0.7567945122718811, 0.0, ... |
# | 000018acd19b4ad3 | [0.19296137988567352, 0.0,... |
# | 00001bc2c4027449 | [0.6756594777107239, 0.0, ... |
# | 00001bcc92282a38 | [0.14417380094528198, 0.0,... |
# +------------------+-------------------------------+
# +-------------------------------+
# |          DisplayNames         |
# +-------------------------------+
# ...

# %%
import array
test_data = test_data.pack_columns(column_name_prefix='deep_features', dtype=array.array)

# %%
test_data = test_data.stack('DisplayNames', new_column_name='DisplayName')

# %%
test_data
# Out:
# Columns:
# 	ImageID	str
# 	deep_features	array
# 	DisplayName	str
#
# Rows: 1000000
#
# Data:
# +------------------+-------------------------------+-----------------+
# |     ImageID      |         deep_features         |   DisplayName   |
# +------------------+-------------------------------+-----------------+
# | 000002b66c9c498e | [0.25520071387290955, 0.0,... |     Birthday    |
# | 000002b66c9c498e | [0.25520071387290955, 0.0,... |    Friendship   |
# | 000002b66c9c498e | [0.25520071387290955, 0.0,... |     Cuisine     |
# | 000002b66c9c498e | [0.25520071387290955, 0.0,... |      Event      |
# | 000002b66c9c498e | [0.25520071387290955, 0.0,... |      Torte      |
# | 000002b66c9c498e | [0.25520071387290955, 0.0,... | Cake decorating |
# | 000002b66c9c498e | [0.25520071387290955, 0.0,... |   Anniversary   |
# | 000002b66c9c498e | [0.25520071387290955, 0.0,... |      Party      |
# | 000002b66c9c498e | [0.25520071387290955, 0.0,... |    Community    |
# ...

# %%
# %time model = tc.image_classifier.create(test_data, feature='deep_features', target='DisplayName', max_iterations=200, batch_size=4, validation_set=None, solver='lbfgs') # , model='squeezenet_v1.1'', solver='lbfgs'
# Out:
# ...
# Download completed: /var/tmp/model_cache/resnet-50-TuriCreate-6.0.h5
# Logistic regression:
# --------------------------------------------------------
# Number of examples          : 1000000
# Number of classes           : 8592
# Number of feature columns   : 1
# Number of unpacked features : 2048
# Number of coefficients      : 17602959
# Starting L-BFGS
# --------------------------------------------------------
# +-----------+----------+-----------+--------------+-------------------+
# | Iteration | Passes   | Step size | Elapsed Time | Training Accuracy |
# +-----------+----------+-----------+--------------+-------------------+
